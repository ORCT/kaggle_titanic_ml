# %% [markdown]
# <a href="https://www.kaggle.com/code/noibl0/titanic-ml?scriptVersionId=131705288" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import OrdinalEncoder
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report
from xgboost import XGBClassifier

# %%
def convert_columns(df):
    df['Cabin'].fillna(0, inplace=True)
    df['Cabin'] = np.where(df['Cabin'] == 0, 0, 1)
    return df

# %%
def select_drop_features(df, cardinality=6):
    # over 30 cardinality column will be dropped.
    
    columns_to_drop = df.apply(lambda x: x.nunique() > cardinality)
    return columns_to_drop

# %%
def feature_engineering(df, drop_features):
    X = df.drop(columns=drop_features[drop_features].index)
    return X

# %%
def split_X_y(df):
    target = 'Survived'
    X = df.drop(columns=target)
    y = df[target]
    return X, y

# %%
df = pd.read_csv('/kaggle/input/titanic/train.csv')
df_t = pd.read_csv('/kaggle/input/titanic/test.csv')

# %%
df = convert_columns(df)
df_t = convert_columns(df_t)
drop_features = select_drop_features(df)
df = feature_engineering(df, drop_features)
X_test = feature_engineering(df_t, drop_features)
X_train, y_train = split_X_y(df)

# %% [markdown]
# Comparing the train data with the test data, Survived feature is the target to be predicted.

# %% [markdown]
# Select the features to predict target using in ML.

# %%
pipe = make_pipeline(
    OrdinalEncoder(),
    SimpleImputer(),
    XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
)

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('ordinalencoder', OrdinalEncoder()),
#                 ('simpleimputer', SimpleImputer()),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, gamma=None, gpu_id=None,
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None, learning_rate=1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=2, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, n_estimators=2,
#                                n_jobs=None, num_parallel_tree=None,
#                                predictor=None, random_state=None, ...))])

# %%
params = {
    "xgbclassifier__max_depth": [2, 4, 6],
    "xgbclassifier__min_child_weight": [2, 4, 8],
    "xgbclassifier__colsample_bytree": [0.6, 0.8, 1.0],
}

# %%
from sklearn.model_selection import GridSearchCV

grid_search = GridSearchCV(pipe, param_grid=params, scoring="roc_auc", cv=3, verbose=3)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.6, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.839 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.817 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.852 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.842 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.807 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.841 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.814 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.845 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.818 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.845 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.807 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.841 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.814 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.845 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.818 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.853 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=0.8, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.845 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.801 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.857 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=2;, score=0.836 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.801 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.857 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=4;, score=0.836 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.801 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.857 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=2, xgbclassifier__min_child_weight=8;, score=0.836 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.818 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.860 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=2;, score=0.837 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.824 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.856 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=4;, score=0.848 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.819 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.856 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=4, xgbclassifier__min_child_weight=8;, score=0.836 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.818 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.860 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=2;, score=0.839 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.824 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.856 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=4;, score=0.849 total time=   0.0s
# [CV 1/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.819 total time=   0.0s
# [CV 2/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.856 total time=   0.0s
# [CV 3/3] END xgbclassifier__colsample_bytree=1.0, xgbclassifier__max_depth=6, xgbclassifier__min_child_weight=8;, score=0.836 total time=   0.0s
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('ordinalencoder', OrdinalEncoder()),
#                                        ('simpleimputer', SimpleImputer()),
#                                        ('xgbclassifier',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       gamma=...
#                                                       max_delta_step=None,
#                                                       max_depth=2,
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       n_estimators=2,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None, ...))]),
#              param_grid={'xgbclassifier__colsample_bytree': [0.6, 0.8, 1.0],
#                          'xgbclassifier__max_depth': [2, 4, 6],
#                          'xgbclassifier__min_child_weight': [2, 4, 8]},
#              scoring='roc_auc', verbose=3)

# %%
print("최적 하이퍼파라미터: ", grid_search.best_params_)
print("최적 AUC: ", grid_search.best_score_)
# Out:
# 최적 하이퍼파라미터:  {'xgbclassifier__colsample_bytree': 1.0, 'xgbclassifier__max_depth': 6, 'xgbclassifier__min_child_weight': 4}
# 최적 AUC:  0.8428482408206307

# %%
y_pred = grid_search.predict(X_train)
print(classification_report(y_train, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86       549
#            1       0.88      0.58      0.70       342
#
#     accuracy                           0.81       891
#    macro avg       0.84      0.77      0.78       891
# weighted avg       0.82      0.81      0.80       891

# %%
y_pred = grid_search.predict(X_test)
submission = pd.DataFrame({'PassengerId' : df_t['PassengerId'], 'Survived' : y_pred})
submission.to_csv('submission.csv', index=False)
